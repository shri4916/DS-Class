# %% [markdown]
# <a href="https://colab.research.google.com/github/shri4916/DS-Class/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python
#
# Python is a general purpose high level programming language.
#
# Python was developed by Guido Van Rossam in 1989 while working at National Research Institute at Netherlands.
#
# But officially Python was made available to public in 1991. The official Date of Birth for
#
# Python is : Feb 20th 1991.
#
# Python is recommended as first programming language for beginners.

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World
