# %% [markdown]
# <a href="https://colab.research.google.com/github/shri4916/DS-Class/blob/main/2_Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bool (0.1)
int = 1
print(int)
list=[10,10.5,'Data Science',True,10]
print(list)
list.remove(10)
print(list)
list.append('shri')
print(list)
# Out:
# 1
# [10, 10.5, 'Data Science', True, 10]
# [10.5, 'Data Science', True, 10]
# [10.5, 'Data Science', True, 10, 'shri']
