# %% [markdown]
# <a href="https://colab.research.google.com/github/shri4916/DS-Class/blob/main/9_Python_basics_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dictionary Data Structure
# ֍We can use List, Tuple and Set to represent a group of individual objects as a single entity
#
# ֍ If we want to represent a group of objects as key-value pairs then we should go for Dictionary.
#
# rollno ---- name
#
# phone number -- address
#
# ipaddress --- domain name
#
# ֍Duplicate keys are not allowed but values can be duplicated.
#
# ֍Hetrogeneous objects are allowed for both key and values.
#
# ֍Insertion order is not preserved.
#
# ֍Dictionaries are mutable.
#
# ֍Dictionaries are dynamic.
#
# ֍Indexing and slicing concepts are not applicable.

# %% [markdown]
# #How to create a dictionary

# %%
#creating an empty dictionary
d = {}
a = dict()

# %%
# Adding data in dictionary
d[1] = "A"
d[2] = "B"
d[3] = "C"
d[1] = "D"
print(d)
# Out:
# {1: 'D', 2: 'B', 3: 'C'}

# %%
#another way to create a dictionary
a = {"Name":"Shri", "Age": 21, "City": "Pune"}
print(a)
# Out:
# {'Name': 'Shri', 'Age': 21, 'City': 'Pune'}

# %%
#How to fetch a single value form dictionary
print(a["Name"])
print(a.get("Taluka"))
print(a["Taluka"])
#if i give a invalid key diretly to dearch it will give error, but when I use .get for invallid key it will geve "None"
# Out:
# Niwas
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1598781254.py in <cell line: 0>()
#       2 print(a["Name"])
#       3 print(a.get("Taluka"))
# ----> 4 print(a["Taluka"])
#       5 #if i give a invalid key diretly to dearch it will give error, but when I use .get for invallid key it will geve "None"
#
# KeyError: 'Taluka'

# %% [markdown]
# #How to Update Dictionaries?
# ֍ syntax: d[key] = value
#
# ֍ If the key is not available then a new entry will be added to the dictionary with the specified key-value pair.
#
# ֍If the key is already available then old value will be replaced with new value.

# %%
a["Name"] = "Niwas"
a ["hight"] = 175
print(a)
# Out:
# {'Name': 'Niwas', 'Age': 21, 'City': 'Pune', 'NAme': 'Niwas', 'hight': 175}

# %% [markdown]
# #How to Delete Elements from Dictionary?

# %%
#1. del d[key]
# If deletes entry associated with the specified key.
#If the key is not available then we will get KeyError.
a = {'Name': 'Niwas', 'Age': 21, 'City': 'Pune', 'NAme': 'Niwas', 'hight': 175}
del a["NAme"]
print(a)
del a["Taluka"]
# Out:
# {'Name': 'Niwas', 'Age': 21, 'City': 'Pune', 'hight': 175}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-581790810.py in <cell line: 0>()
#       5 del a["NAme"]
#       6 print(a)
# ----> 7 del a["Taluka"]
#
# KeyError: 'Taluka'

# %% [markdown]
# #  .clear()
# To remove all entries from dictionary

# %%
a = {'Name': 'Niwas', 'Age': 21, 'City': 'Pune', 'NAme': 'Niwas', 'hight': 175}
a.clear()
print(a)
# Out:
# {}

# %%
# 3. del(): To delete total dict.
d={100:"apple",200:"ball",300:"cat"}
print(d)
del d
print(d) # we have deleted the dict hence throwing error
# Out:
# {100: 'apple', 200: 'ball', 300: 'cat'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-918965604.py in <cell line: 0>()
#       3 print(d)
#       4 del d
# ----> 5 print(d) # we have deleted the dict hence throwing error
#
# NameError: name 'd' is not defined

# %% [markdown]
# #Important Functions of Dictionary:

# %%
# to explacitely create a dictionary
d = dict()
type(d)
# Out:
# dict

# %%
d = dict([(1,"A"), (2,"B")])
print(d)
# Out:
# {1: 'A', 2: 'B'}

# %% [markdown]
# Length

# %%
# to find lenghth of dictionary
d = dict([(1,"A"), (2,"B")])
print(len(d))
# Out:
# 2

# %% [markdown]
# #Nested dictioary

# %%
d = {
    "Student1" : {"Name": "Shri", "Age": 21},
    "Student2" : {"Name": "Niwas", "Age": 23},
    "Student3" : {"Name": "Ambad", "Age": 25},
}
print (d)
# Out:
# {'Student1': {'Name': 'Shri', 'Age': 21}, 'Student2': {'Name': 'Niwas', 'Age': 23}, 'Student3': {'Name': 'Ambad', 'Age': 25}}
